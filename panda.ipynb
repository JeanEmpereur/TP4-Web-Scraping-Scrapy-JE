# %%
import pandas as pd

# %%
df = pd.read_csv('./WebCrawler/WebCrawler/spiders/bours.csv')
df
# Out:
#      cours                        date              indice  maxVal  minVal  \
# 0    9.082  2022-10-26 15:16:50.200543  CREDIT AGRICOLE SA   9.142   9.044
# 1   132.02  2022-10-26 15:16:50.204601         AIR LIQUIDE  134.22  131.28
# 2   105.38  2022-10-26 15:16:50.206058              AIRBUS  105.88   104.3
# 3    19.98  2022-10-26 15:16:50.206845              ALSTOM   20.03   19.23
# 4   47.965  2022-10-26 15:16:50.207561              DANONE  48.565  47.685
# ..     ...                         ...                 ...     ...     ...
# 72   273.1  2022-10-26 15:17:35.106583     TELEPERFORMANCE   275.6   271.1
# 73   52.67  2022-10-26 15:17:35.107317       TOTALENERGIES   53.37   52.41
# 74   22.51  2022-10-26 15:17:35.108047              VEOLIA   23.07   22.49
# 75   8.206  2022-10-26 15:17:35.108763             VIVENDI   8.296   8.164
# 76    44.2  2022-10-26 15:17:35.109439           WORLDLINE   44.74    43.3
#
#    openVal page    var
# 0    9.111    1    NaN
# ...

# %%
df
# Out:
#        cours                        date              indice    maxVal  \
# 0     9.090   2022-10-26 15:02:39.313725  CREDIT AGRICOLE SA    9.142
# 1   131.920   2022-10-26 15:02:39.316766         AIR LIQUIDE  134.220
# 2   105.380   2022-10-26 15:02:39.319412              AIRBUS  105.880
# 3    19.965   2022-10-26 15:02:39.320567              ALSTOM   20.030
# 4    47.950   2022-10-26 15:02:39.321419              DANONE   48.565
# ..       ...                         ...                 ...       ...
# 72     273.2  2022-10-26 15:09:04.633637     TELEPERFORMANCE     275.6
# 73     52.58  2022-10-26 15:09:04.634322       TOTALENERGIES     53.37
# 74     22.49  2022-10-26 15:09:04.635112              VEOLIA     23.07
# 75     8.212  2022-10-26 15:09:04.635820             VIVENDI     8.296
# 76     44.02  2022-10-26 15:09:04.636619           WORLDLINE     44.74
#
#       minVal   openVal     var
# 0     9.044     9.111   -0.04%
# 1   131.280   132.800   -0.44%
# ...
